# %% [markdown]
# 截止目前，诸位读者已经掌握了使用飞桨完成深度学习建模的方法，并且可以编写相当强大的模型。如果将每个模型部分均展开，整个模型实现有几百行代码，可以灵活的实现各种建模过程中的需求。
#
# <center><img src="https://ai-studio-static-online.cdn.bcebos.com/d6426ebba33544d2ba44f34d02484a1e647fb13aea5e4ceabe0f76e14f293c9f"  width="800" ></center>
# <center><br>“横纵式”教学法编写相当强大的模型<br/></center>
# <br><br/>
#
# 本章内容覆盖了使用飞桨建模各方面的基础知识，但仅以手写数字识别为案例，还难以覆盖各个领域的建模经验。从下一章开始，我们正式进入本教程的第二部分：以推荐、计算机视觉和自然语言处理等多个领域的任务为例，讲述各行各业最为常用的模型实现，并介绍更多使用飞桨的知识。

# %% [markdown]
# ## 作业
#
# 1. 正确运行模型的极简版代码，分析训练过程中可能出现的问题或值得优化的地方，通过以下几点优化：
#
# （1）样本：增加数据是否有效（可观察模型效果随数据量增加的变化曲线）？数据增强的方法？or ?
#
# （2）假设：改进网络模型，更多层？ResNet？or ？
#
# （3）损失：尝试各种Loss，分类任务只有一种合适的loss吗？ or ?
#
# （4）优化：尝试各种优化算法和学习率，介绍过的四种? or?
#
# 目标：尽可能使模型在MNIST测试集上的分类准确率最高且具有较快的训练/预测性能，提交实现模型的 分类准确率（附上模型代码） 和 训练/预测时间（8:2拆分样本集），我们筛选最优结果前10名进行评奖。
#
#
#
# 2. 使用模型实践：自己手写一些数字，拍照后处理成64×64尺寸后试试模型效果，准或不准的原因是什么？
